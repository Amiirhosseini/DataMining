# %% [markdown]
# ## Amirreza Hosseini
# **9820363**
#
# Introduction to Data Mining
# HomeWork 1 <br>
# Q5

# %%
import pandas as pd

# %% [markdown]
# 1-read the csv file and store it in a dataframe and show the Data frame

# %%
smartphone = pd.read_csv('./Smartphone.csv', sep=',')

smartphone
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
#show the smartphone type of object
type(smartphone)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 2-discribe the smartphone df

# %%
smartphone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
#type of each column
smartphone.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %% [markdown]
# 3-show every record when blue is true and internal memory is greater than 10

# %%
query=smartphone[(smartphone['blue'] == True) & (smartphone['int_memory'] > 10)]
query
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 4              1821     1          1.2         0  13       1          44
# 8              1445     1          0.5         0   0       0          53
# 11             1520     1          2.2         0   5       1          33
# ...             ...   ...          ...       ...  ..     ...         ...
# 1990           1617     1          2.4         0   8       1          36
# 1992            674     1          2.9         1   1       0          21
# 1993           1467     1          0.5         0   0       0          18
# 1996           1965     1          2.6         1   0       0          39
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# 4-show the first and last smartphones of the data frame sorted by fc

# %%
smartphone[smartphone['fc'] == smartphone['fc'].max()]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1705           1290     1          1.4         1  19       1          35
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width  ram  sc_h  sc_w  \
# 1705    0.3        110        4  ...        405       742  879    16     2
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 1705          8        1             0     0            0
#
# [1 rows x 21 columns]

# %%
smartphone[smartphone['fc'] == smartphone['fc'].min()]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1              1021     1          0.5         1   0       1          53
# 3               615     1          2.5         0   0       0          10
# 7              1954     0          0.5         1   0       0          24
# 8              1445     1          0.5         0   0       0          53
# 10              769     1          2.9         1   0       0           9
# ...             ...   ...          ...       ...  ..     ...         ...
# 1971            538     0          1.1         1   0       1          25
# 1984            797     0          2.2         1   0       0          37
# 1993           1467     1          0.5         0   0       0          18
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# 5-add new column to the df name is clock_rate:<br> <br>
# -when the clock_speed is less than 1 then the clock_rate is low <br>
# -when the clock_speed is greater than 1 and less than 2 then the clock_rate is mid <br>
# -when the clock_speed is greater than 2 then the clock_rate is high

# %%
smartphone['clock_rate'] = smartphone['clock_speed'].apply(lambda x: 'low' if x < 1 else 'mid' if x < 2 else 'high')
#show the df
smartphone
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %% [markdown]
# 6-show the heatmap chart of attributes and find strong relations

# %%
import seaborn as sns
import matplotlib as mp

# %%
sns.heatmap(smartphone.corr(), annot=True,linewidths=0.5, cmap='YlGnBu')
mp.pyplot.gcf().set_size_inches(15, 15)
mp.pyplot.tight_layout()
mp.pyplot.show()

# %% [markdown]
# **Report from heatmap:** <br>
#
# Based on the above chart, it can be seen that the blue squares are somehow shows the attributes that are related together like: <br>
# four_g & three_g - pc & fc -  screen height (sc_h) & screen width(sc_w) - pixel resolution height (px_height) & pixel resolution width (px_width) - ram & price_range

# %% [markdown]
# choose the attributes with high correlations upper than 0.5

# %%
df2=smartphone[['four_g','three_g','pc','fc','sc_h','sc_w','px_height','px_width','ram','price_range']]
df2
# Out:
#       four_g  three_g  pc  fc  sc_h  sc_w  px_height  px_width   ram  \
# 0          0        0   2   1     9     7         20       756  2549
# 1          1        1   6   0    17     3        905      1988  2631
# 2          1        1   6   2    11     2       1263      1716  2603
# 3          0        1   9   0    16     8       1216      1786  2769
# 4          1        1  14  13     8     2       1208      1212  1411
# ...      ...      ...  ..  ..   ...   ...        ...       ...   ...
# 1995       1        1  14   0    13     4       1222      1890   668
# 1996       0        1   3   0    11    10        915      1965  2032
# 1997       1        1   3   1     9     1        868      1632  3057
# 1998       1        1   5   4    18    10        336       670   869
# 1999       1        1  16   5    19     4        483       754  3919
#
#       price_range
# 0               1
# 1               2
# 2               2
# 3               2
# 4               1
# ...           ...
# ...

# %%
sns.pairplot(df2)

# %%
from scipy.stats import spearmanr

#calculate spearman correlation for each attributes of df2
for i in df2.columns:
    for j in df2.columns:
        if i != j:
            corr, _ = spearmanr(df2[i], df2[j])
            print('Spearmans correlation between %s and %s: %.3f' % (i, j, corr))
# Out:
# Spearmans correlation between four_g and three_g: 0.584
# Spearmans correlation between four_g and pc: -0.006
# Spearmans correlation between four_g and fc: -0.024
# Spearmans correlation between four_g and sc_h: 0.027
# Spearmans correlation between four_g and sc_w: 0.035
# Spearmans correlation between four_g and px_height: -0.023
# Spearmans correlation between four_g and px_width: 0.008
# Spearmans correlation between four_g and ram: 0.007
# Spearmans correlation between four_g and price_range: 0.015
# Spearmans correlation between three_g and four_g: 0.584
# Spearmans correlation between three_g and pc: -0.001
# Spearmans correlation between three_g and fc: -0.014
# Spearmans correlation between three_g and sc_h: 0.012
# Spearmans correlation between three_g and sc_w: 0.024
# Spearmans correlation between three_g and px_height: -0.027
# Spearmans correlation between three_g and px_width: 0.001
# Spearmans correlation between three_g and ram: 0.016
# ...

# %% [markdown]
# 7- histogram of the battery_power feild

# %%
#histogram of battery power based on the number of record
mp.pyplot.hist(smartphone['battery_power'], bins=10, color='blue', edgecolor='black', alpha=0.7)
#change the axis
mp.pyplot.xlabel('battery_power')
# Out:
# Text(0.5, 0, 'battery_power')
